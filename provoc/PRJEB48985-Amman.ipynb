# %% [markdown]
# # PRJEB48985 - Amman et al.
#
# Article link: []().

# %%
suppressPackageStartupMessages({
    library(provoc)
    library(here)
    library(ggplot2)
    library(lubridate)
})

prj <- "PRJEB48985"
lineages_in_paper <- c("B.1.1.318", "B.1.258", "B.1.351", "B.1.1.7", "B.1.617.2", "B.1.621", "BA.1", "BA.2")

# %%
coco <- read.csv(
    here(
        "data/processed/",
        paste0(prj, "_processed.csv.gz")
    )
)
coco$mutation <- parse_mutations(coco$label)
head(coco)
# Out:
#   position     label    mutation frequency coverage count        sra       date   sample_name avg_spot_len      bases bioproject
# 1    10025 +10026.AA ins:10026:2         0     4616     0 ERR7426134 2020-07-23 SAMEA10801705          502 1613677996 PRJEB48985
# 2    10046  +10047.T ins:10047:1         0     4543     0 ERR7426134 2020-07-23 SAMEA10801705          502 1613677996 PRJEB48985
# 3    10065  +10066.A ins:10066:1         0     4536     0 ERR7426134 2020-07-23 SAMEA10801705          502 1613677996 PRJEB48985
# 4    10075  +10076.T ins:10076:1         0     4571     0 ERR7426134 2020-07-23 SAMEA10801705          502 1613677996 PRJEB48985
# 5    10619  +10620.A ins:10620:1         0    12472     0 ERR7426134 2020-07-23 SAMEA10801705          502 1613677996 PRJEB48985
# 6    10626  +10627.A ins:10627:1         0    12472     0 ERR7426134 2020-07-23 SAMEA10801705          502 1613677996 PRJEB48985

# %%
barcodes <- provoc::usher_barcodes()
print("Lineages not in barcodes:")
print(setdiff(lineages_in_paper, rownames(barcodes)))
available_lineages <- intersect(lineages_in_paper, rownames(barcodes))
barcodes <- filter_lineages(barcodes, available_lineages)
dim(barcodes)
# Out:
# [1] "Lineages not in barcodes:"
# character(0)
# [1]   8 155

# %%
system.time(
    res <- provoc(count / coverage ~ .,
        data = coco,
        lineage_defs = barcodes,
        by = "sra")
)
head(res)
# Out:
# Warning messages:
# 1: In rep(10, length = nrow(lineage_defs)) :
#   first element used of 'length.out' argument
# 2: In optim(theta.old, fun, gradient, control = control, method = method,  :
#   one-dimensional optimization by Nelder-Mead is unreliable:
# use "Brent" or optimize() directly
# 3: In optim(theta.old, fun, gradient, control = control, method = method,  :
#   one-dimensional optimization by Nelder-Mead is unreliable:
# use "Brent" or optimize() directly
# 4: In optim(theta.old, fun, gradient, control = control, method = method,  :
#   one-dimensional optimization by Nelder-Mead is unreliable:
# use "Brent" or optimize() directly
# 5: In optim(theta.old, fun, gradient, control = control, method = method,  :
#   one-dimensional optimization by Nelder-Mead is unreliable:
# use "Brent" or optimize() directly
# Call: count/coverage ~ .
#
# Mutations in lineage definitions:  155
# Summary of percent of mutations in data used:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# 0.01366 0.01366 0.01366 0.01366 0.01366 0.01366
#
# All models converged.
#
# Top 6 lineages:
#      rho ci_low ci_high   lineage        sra       date   sample_name avg_spot_len    bases bioproject
# 1  0.004     NA      NA      BA.2 ERR7426134 2020-07-23 SAMEA10801705          502 1.61e+09 PRJEB48985
# 5 <0.001     NA      NA B.1.1.318 ERR7426134 2020-07-23 SAMEA10801705          502 1.61e+09 PRJEB48985
# 4 <0.001     NA      NA   B.1.1.7 ERR7426134 2020-07-23 SAMEA10801705          502 1.61e+09 PRJEB48985
# 6 <0.001     NA      NA   B.1.351 ERR7426134 2020-07-23 SAMEA10801705          502 1.61e+09 PRJEB48985
# 3 <0.001     NA      NA   B.1.621 ERR7426134 2020-07-23 SAMEA10801705          502 1.61e+09 PRJEB48985
# 2 <0.001     NA      NA      BA.1 ERR7426134 2020-07-23 SAMEA10801705          502 1.61e+09 PRJEB48985

# %%
options(repr.plot.width = 15, repr.plot.height = 12)

res$date <- lubridate::ymd(res$date)

gg <- autoplot(res, date_col = "date") + facet_wrap(~location) +
    geom_smooth(formula = y ~ x, se = FALSE, method = "loess") +
    theme_bw()
suppressWarnings(print(gg))
# Out:
# Error in `combine_vars()`:
#
# ! At least one layer must contain all faceting variables: `location`
#
# ✖ Plot is missing `location`
#
# ✖ Layer 1 is missing `location`
#
# ✖ Layer 2 is missing `location`
#
#      ▆
#
#   1. ├─base::suppressWarnings(print(gg))
#
#   2. │ └─base::withCallingHandlers(...)
#
#   3. ├─base::print(gg)
#
#   4. └─ggplot2 (local) `print.ggplot2::ggplot`(gg)
#
#   5.   ├─ggplot2::ggplot_build(x)
#
#   6.   └─ggplot2 (local) `ggplot_build.ggplot2::ggplot`(x)
#
#   7.     └─layout$setup(data, plot@data, plot@plot_env)
#
#   8.       └─ggplot2 (local) setup(..., self = self)
#
#   9.         └─self$facet$compute_layout(data, self$facet_params)
#
#  10.           └─ggplot2 (local) compute_layout(..., self = self)
#
#  11.             └─ggplot2::combine_vars(data, params$plot_env, vars, drop = params$drop)
#
#  12.               └─cli::cli_abort(...)
#
#  13.                 └─rlang::abort(...)
